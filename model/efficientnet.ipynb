# %%
def efficientnet():
    model = efn.EfficientNetB3(
        include_top=False,
        weights="imagenet",
        input_shape=(256, 256, 3))
    
    # add new classifier layers
    x = layers.Conv2DTranspose(filters=640, kernel_size=(2, 2), strides=(2, 2), use_bias=False)(model.layers[-36].output)

    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Conv2DTranspose(filters=160, kernel_size=(4, 4), strides=(4, 4), use_bias=False)(x)
    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Conv2DTranspose(filters=40, kernel_size=(2, 2), strides=(2, 2), use_bias=False)(x)
    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Conv2DTranspose(filters=3, kernel_size=(2, 2), strides=(2, 2), use_bias=False)(x)
    
    # define new model
    model = Model(inputs=model.inputs, outputs=x)

    model.compile()
    model.summary()
    return model

# %%
def efficientnet_generator():
    model = efn.EfficientNetB3(
        include_top=False,
        weights="imagenet",
        input_shape=(256, 256, 3))
    
    """
    add pooling between conv2d and increase kernel_size(increases output for layer)
    increase strides?
    size of output (size of input - 1) * (stride) + kernel size
    """

    # add new classifier layers
    x = layers.Conv2DTranspose(filters=640, kernel_size=(2, 2), strides=(2, 2), use_bias=False)(model.output)
    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1))(x)
    x = tfa.layers.InstanceNormalization()(x)

    x = layers.Conv2DTranspose(filters=160, kernel_size=(8, 8), strides=(4, 4), use_bias=False)(x)
    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = tfa.layers.InstanceNormalization()(x)

    x = layers.Conv2DTranspose(filters=40, kernel_size=(4, 4), strides=(4, 4), use_bias=False)(x)
    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = tfa.layers.InstanceNormalization()(x)

    x = layers.Conv2DTranspose(filters=3, kernel_size=(4, 4), strides=(4, 4), use_bias=False)(x)
    #x = layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1))(x)
    x = tfa.layers.InstanceNormalization()(x)
    
    # define new model
    model = Model(inputs=model.inputs, outputs=x)

    model.compile()
    model.summary()
    return model

# %%
import os
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import (Dense, 
                                     BatchNormalization, 
                                     LeakyReLU, 
                                     Reshape, 
                                     Conv2DTranspose,
                                     Conv2D,
                                     Dropout,
                                     Flatten,
                                     multiply)

import tensorflow_addons as tfa

from tensorflow.keras.applications import EfficientNetB0
#from tensorflow.keras.applications import EfficientNetB7
from keras.models import Model
from keras.models import Sequential
import efficientnet.tfkeras
import efficientnet.keras as efn

# %%
class ReflectionPadding2D(layers.Layer):
    """Implements Reflection Padding as a layer.

    Args:
        padding(tuple): Amount of padding for the
        spatial dimensions.

    Returns:
        A padded tensor with the same type as the input tensor.
    """


    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        super(ReflectionPadding2D, self).__init__(**kwargs)

    def call(self, input_tensor, mask=None):
        padding_width, padding_height = self.padding
        padding_tensor = [
            [0, 0],
            [padding_height, padding_height],
            [padding_width, padding_width],
            [0, 0],
        ]
        return tf.pad(input_tensor, padding_tensor, mode="REFLECT")

# %%
def efficient_block(x, name):

    efficientnet_model = efn.EfficientNetB3(
            include_top=False,
            weights="imagenet",
            input_shape=(256, 256, 3)
            )

    inputs = x
    
    for layer in efficientnet_model.layers:
        layer._name = layer.name + str(name)
    
    #efficientnet_model.trainable = False
    
    x = efficientnet_model.layers[30](inputs)
   
    x1 = efficientnet_model.layers[31](x)
    x = efficientnet_model.layers[32](x1)
    x = efficientnet_model.layers[33](x)
    x = efficientnet_model.layers[34](x)
    x2 = efficientnet_model.layers[35](x)
    x = tf.keras.layers.Multiply()([x1, x2])

    x = efficientnet_model.layers[37](x)
    x5 = efficientnet_model.layers[38](x)
    x = efficientnet_model.layers[39](x5)
    x = efficientnet_model.layers[40](x)
    x = efficientnet_model.layers[41](x)
    x = efficientnet_model.layers[42](x)
    x = efficientnet_model.layers[43](x)
    
    x3 = efficientnet_model.layers[44](x)
    x = efficientnet_model.layers[45](x3)
    x = efficientnet_model.layers[46](x)
    x = efficientnet_model.layers[47](x)
    x4 = efficientnet_model.layers[48](x)
    x = tf.keras.layers.Multiply()([x3, x4])
    
    x = efficientnet_model.layers[50](x)
    x = efficientnet_model.layers[51](x)

    x6 = efficientnet_model.layers[52](x)
    x9 = tf.keras.layers.Add()([x5, x6])
    
    x = efficientnet_model.layers[54](x9)
    x = efficientnet_model.layers[55](x)
    x = efficientnet_model.layers[56](x)
    x = efficientnet_model.layers[57](x)
    x = efficientnet_model.layers[58](x)
    
    x7 = efficientnet_model.layers[59](x)
    x = efficientnet_model.layers[60](x7)
    x = efficientnet_model.layers[61](x)
    x = efficientnet_model.layers[62](x)
    x8 = efficientnet_model.layers[63](x)
    x = tf.keras.layers.Multiply()([x7, x8])
    
    x = efficientnet_model.layers[65](x)
    x = efficientnet_model.layers[66](x)
    x10 = efficientnet_model.layers[67](x)
    x = tf.keras.layers.Add()([x9, x10])
    
    x = efficientnet_model.layers[69](x)
    x = efficientnet_model.layers[70](x)
    x = efficientnet_model.layers[71](x)
    x = layers.Conv2DTranspose(144, kernel_size=(1,1), strides=(1,1), padding="same", use_bias=False)(x)
    
    #model = keras.models.Model(inputs, x, name=name)
    """
    x=efficientnet_model.layers[29](x)
    for layer in efficientnet_model.layers[30:60]:
        x=layer(x)
    """
    return x

# %%
def efficientnet_generator(
    filters = 64,
    num_efficient_blocks=5,
    name=None,
):

    inputs = tf.keras.layers.Input(shape=[256,256,3])

    x = ReflectionPadding2D(padding=(3, 3))(inputs)
    x = layers.Conv2D(filters, (7, 7), use_bias=False)(x)
    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Activation("relu")(x)

    #downsample
    x = layers.Conv2D(64, kernel_size=(3,3), strides=(2,2), padding="same", use_bias=False)(x)
    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(144, kernel_size=(3,3), strides=(2,2), padding="same", use_bias=False)(x)
    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Activation("relu")(x)

    #efficient blocks

    #for _ in range(num_efficient_blocks):
    x = efficient_block(x, 'block1')
    x = efficient_block(x, 'block2')
    x = efficient_block(x, 'block3')
    x = efficient_block(x, 'block4')
    x = efficient_block(x, 'block5')
    x = efficient_block(x, 'block6')
    x = efficient_block(x, 'block7')
    x = efficient_block(x, 'block8')
    x = efficient_block(x, 'block9')


    # Upsampling
    x = layers.Conv2DTranspose(64, kernel_size=(3,3), strides=(2,2), padding="same", use_bias=False)(x)
    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2DTranspose(3, kernel_size=(3,3), strides=(2,2), padding="same", use_bias=False)(x)
    x = tfa.layers.InstanceNormalization()(x)
    x = layers.Activation("relu")(x)

    # Final block
    x = ReflectionPadding2D(padding=(3, 3))(x)
    x = layers.Conv2D(3, (7, 7), padding="valid")(x)
    x = layers.Activation("tanh")(x)

    model = keras.models.Model(inputs, x, name=name)
    
    model.compile()
    model.summary()
    return model

# %%
efficientnet_generator(
    filters = 64,
    num_efficient_blocks=1,
    name=None,
)
# Out:
# Model: "functional_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_62 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# reflection_padding2d_27 (Reflec (None, 262, 262, 3)  0           input_62[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 256, 256, 64) 9408        reflection_padding2d_27[0][0]
# __________________________________________________________________________________________________
# instance_normalization_74 (Inst (None, 256, 256, 64) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 256, 256, 64) 0           instance_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 128, 128, 64) 36864       activation_81[0][0]
# __________________________________________________________________________________________________
# instance_normalization_75 (Inst (None, 128, 128, 64) 128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 128, 128, 64) 0           instance_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 64, 144)  82944       activation_82[0][0]
# __________________________________________________________________________________________________
# instance_normalization_76 (Inst (None, 64, 64, 144)  288         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 64, 64, 144)  0           instance_normalization_76[0][0]
# __________________________________________________________________________________________________
# block2a_bnblock1 (BatchNormaliz (None, 64, 64, 144)  576         activation_83[0][0]
# __________________________________________________________________________________________________
# block2a_activationblock1 (Activ (None, 64, 64, 144)  0           block2a_bnblock1[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeezeblock1 (Globa (None, 144)          0           block2a_activationblock1[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshapeblock1 (Resha (None, 1, 1, 144)    0           block2a_se_squeezeblock1[1][0]
# __________________________________________________________________________________________________
# block2a_se_reduceblock1 (Conv2D (None, 1, 1, 6)      870         block2a_se_reshapeblock1[1][0]
# __________________________________________________________________________________________________
# block2a_se_expandblock1 (Conv2D (None, 1, 1, 144)    1008        block2a_se_reduceblock1[1][0]
# __________________________________________________________________________________________________
# multiply_63 (Multiply)          (None, 64, 64, 144)  0           block2a_activationblock1[1][0]
#                                                                  block2a_se_expandblock1[1][0]
# __________________________________________________________________________________________________
# block2a_project_convblock1 (Con (None, 64, 64, 32)   4608        multiply_63[0][0]
# __________________________________________________________________________________________________
# block2a_project_bnblock1 (Batch (None, 64, 64, 32)   128         block2a_project_convblock1[1][0]
# __________________________________________________________________________________________________
# block2b_expand_convblock1 (Conv (None, 64, 64, 192)  6144        block2a_project_bnblock1[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bnblock1 (BatchN (None, 64, 64, 192)  768         block2b_expand_convblock1[1][0]
# __________________________________________________________________________________________________
# block2b_expand_activationblock1 (None, 64, 64, 192)  0           block2b_expand_bnblock1[1][0]
# __________________________________________________________________________________________________
# block2b_dwconvblock1 (Depthwise (None, 64, 64, 192)  1728        block2b_expand_activationblock1[1
# __________________________________________________________________________________________________
# block2b_bnblock1 (BatchNormaliz (None, 64, 64, 192)  768         block2b_dwconvblock1[1][0]
# __________________________________________________________________________________________________
# block2b_activationblock1 (Activ (None, 64, 64, 192)  0           block2b_bnblock1[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeezeblock1 (Globa (None, 192)          0           block2b_activationblock1[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshapeblock1 (Resha (None, 1, 1, 192)    0           block2b_se_squeezeblock1[1][0]
# __________________________________________________________________________________________________
# block2b_se_reduceblock1 (Conv2D (None, 1, 1, 8)      1544        block2b_se_reshapeblock1[1][0]
# __________________________________________________________________________________________________
# block2b_se_expandblock1 (Conv2D (None, 1, 1, 192)    1728        block2b_se_reduceblock1[1][0]
# __________________________________________________________________________________________________
# multiply_64 (Multiply)          (None, 64, 64, 192)  0           block2b_activationblock1[1][0]
#                                                                  block2b_se_expandblock1[1][0]
# __________________________________________________________________________________________________
# block2b_project_convblock1 (Con (None, 64, 64, 32)   6144        multiply_64[0][0]
# __________________________________________________________________________________________________
# block2b_project_bnblock1 (Batch (None, 64, 64, 32)   128         block2b_project_convblock1[1][0]
# __________________________________________________________________________________________________
# block2b_dropblock1 (FixedDropou (None, 64, 64, 32)   0           block2b_project_bnblock1[1][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 64, 64, 32)   0           block2a_project_bnblock1[1][0]
#                                                                  block2b_dropblock1[1][0]
# __________________________________________________________________________________________________
# block2c_expand_convblock1 (Conv (None, 64, 64, 192)  6144        add_42[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bnblock1 (BatchN (None, 64, 64, 192)  768         block2c_expand_convblock1[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activationblock1 (None, 64, 64, 192)  0           block2c_expand_bnblock1[1][0]
# __________________________________________________________________________________________________
# block2c_dwconvblock1 (Depthwise (None, 64, 64, 192)  1728        block2c_expand_activationblock1[1
# __________________________________________________________________________________________________
# block2c_bnblock1 (BatchNormaliz (None, 64, 64, 192)  768         block2c_dwconvblock1[1][0]
# __________________________________________________________________________________________________
# block2c_activationblock1 (Activ (None, 64, 64, 192)  0           block2c_bnblock1[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeezeblock1 (Globa (None, 192)          0           block2c_activationblock1[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshapeblock1 (Resha (None, 1, 1, 192)    0           block2c_se_squeezeblock1[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduceblock1 (Conv2D (None, 1, 1, 8)      1544        block2c_se_reshapeblock1[1][0]
# __________________________________________________________________________________________________
# block2c_se_expandblock1 (Conv2D (None, 1, 1, 192)    1728        block2c_se_reduceblock1[1][0]
# __________________________________________________________________________________________________
# multiply_65 (Multiply)          (None, 64, 64, 192)  0           block2c_activationblock1[1][0]
#                                                                  block2c_se_expandblock1[1][0]
# __________________________________________________________________________________________________
# block2c_project_convblock1 (Con (None, 64, 64, 32)   6144        multiply_65[0][0]
# __________________________________________________________________________________________________
# block2c_project_bnblock1 (Batch (None, 64, 64, 32)   128         block2c_project_convblock1[1][0]
# __________________________________________________________________________________________________
# block2c_dropblock1 (FixedDropou (None, 64, 64, 32)   0           block2c_project_bnblock1[1][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 64, 64, 32)   0           add_42[0][0]
#                                                                  block2c_dropblock1[1][0]
# __________________________________________________________________________________________________
# block3a_expand_convblock1 (Conv (None, 64, 64, 192)  6144        add_43[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bnblock1 (BatchN (None, 64, 64, 192)  768         block3a_expand_convblock1[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activationblock1 (None, 64, 64, 192)  0           block3a_expand_bnblock1[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_37 (Conv2DTran (None, 64, 64, 144)  27648       block3a_expand_activationblock1[1
# __________________________________________________________________________________________________
# block2a_bnblock2 (BatchNormaliz (None, 64, 64, 144)  576         conv2d_transpose_37[0][0]
# __________________________________________________________________________________________________
# block2a_activationblock2 (Activ (None, 64, 64, 144)  0           block2a_bnblock2[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeezeblock2 (Globa (None, 144)          0           block2a_activationblock2[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshapeblock2 (Resha (None, 1, 1, 144)    0           block2a_se_squeezeblock2[1][0]
# __________________________________________________________________________________________________
# block2a_se_reduceblock2 (Conv2D (None, 1, 1, 6)      870         block2a_se_reshapeblock2[1][0]
# __________________________________________________________________________________________________
# block2a_se_expandblock2 (Conv2D (None, 1, 1, 144)    1008        block2a_se_reduceblock2[1][0]
# __________________________________________________________________________________________________
# multiply_66 (Multiply)          (None, 64, 64, 144)  0           block2a_activationblock2[1][0]
#                                                                  block2a_se_expandblock2[1][0]
# __________________________________________________________________________________________________
# block2a_project_convblock2 (Con (None, 64, 64, 32)   4608        multiply_66[0][0]
# __________________________________________________________________________________________________
# block2a_project_bnblock2 (Batch (None, 64, 64, 32)   128         block2a_project_convblock2[1][0]
# __________________________________________________________________________________________________
# block2b_expand_convblock2 (Conv (None, 64, 64, 192)  6144        block2a_project_bnblock2[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bnblock2 (BatchN (None, 64, 64, 192)  768         block2b_expand_convblock2[1][0]
# __________________________________________________________________________________________________
# block2b_expand_activationblock2 (None, 64, 64, 192)  0           block2b_expand_bnblock2[1][0]
# __________________________________________________________________________________________________
# block2b_dwconvblock2 (Depthwise (None, 64, 64, 192)  1728        block2b_expand_activationblock2[1
# __________________________________________________________________________________________________
# block2b_bnblock2 (BatchNormaliz (None, 64, 64, 192)  768         block2b_dwconvblock2[1][0]
# __________________________________________________________________________________________________
# block2b_activationblock2 (Activ (None, 64, 64, 192)  0           block2b_bnblock2[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeezeblock2 (Globa (None, 192)          0           block2b_activationblock2[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshapeblock2 (Resha (None, 1, 1, 192)    0           block2b_se_squeezeblock2[1][0]
# __________________________________________________________________________________________________
# block2b_se_reduceblock2 (Conv2D (None, 1, 1, 8)      1544        block2b_se_reshapeblock2[1][0]
# __________________________________________________________________________________________________
# block2b_se_expandblock2 (Conv2D (None, 1, 1, 192)    1728        block2b_se_reduceblock2[1][0]
# __________________________________________________________________________________________________
# multiply_67 (Multiply)          (None, 64, 64, 192)  0           block2b_activationblock2[1][0]
#                                                                  block2b_se_expandblock2[1][0]
# __________________________________________________________________________________________________
# block2b_project_convblock2 (Con (None, 64, 64, 32)   6144        multiply_67[0][0]
# __________________________________________________________________________________________________
# block2b_project_bnblock2 (Batch (None, 64, 64, 32)   128         block2b_project_convblock2[1][0]
# __________________________________________________________________________________________________
# block2b_dropblock2 (FixedDropou (None, 64, 64, 32)   0           block2b_project_bnblock2[1][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 64, 64, 32)   0           block2a_project_bnblock2[1][0]
#                                                                  block2b_dropblock2[1][0]
# __________________________________________________________________________________________________
# block2c_expand_convblock2 (Conv (None, 64, 64, 192)  6144        add_44[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bnblock2 (BatchN (None, 64, 64, 192)  768         block2c_expand_convblock2[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activationblock2 (None, 64, 64, 192)  0           block2c_expand_bnblock2[1][0]
# __________________________________________________________________________________________________
# block2c_dwconvblock2 (Depthwise (None, 64, 64, 192)  1728        block2c_expand_activationblock2[1
# __________________________________________________________________________________________________
# block2c_bnblock2 (BatchNormaliz (None, 64, 64, 192)  768         block2c_dwconvblock2[1][0]
# __________________________________________________________________________________________________
# block2c_activationblock2 (Activ (None, 64, 64, 192)  0           block2c_bnblock2[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeezeblock2 (Globa (None, 192)          0           block2c_activationblock2[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshapeblock2 (Resha (None, 1, 1, 192)    0           block2c_se_squeezeblock2[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduceblock2 (Conv2D (None, 1, 1, 8)      1544        block2c_se_reshapeblock2[1][0]
# __________________________________________________________________________________________________
# block2c_se_expandblock2 (Conv2D (None, 1, 1, 192)    1728        block2c_se_reduceblock2[1][0]
# __________________________________________________________________________________________________
# multiply_68 (Multiply)          (None, 64, 64, 192)  0           block2c_activationblock2[1][0]
#                                                                  block2c_se_expandblock2[1][0]
# __________________________________________________________________________________________________
# block2c_project_convblock2 (Con (None, 64, 64, 32)   6144        multiply_68[0][0]
# __________________________________________________________________________________________________
# block2c_project_bnblock2 (Batch (None, 64, 64, 32)   128         block2c_project_convblock2[1][0]
# __________________________________________________________________________________________________
# block2c_dropblock2 (FixedDropou (None, 64, 64, 32)   0           block2c_project_bnblock2[1][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 64, 64, 32)   0           add_44[0][0]
#                                                                  block2c_dropblock2[1][0]
# __________________________________________________________________________________________________
# block3a_expand_convblock2 (Conv (None, 64, 64, 192)  6144        add_45[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bnblock2 (BatchN (None, 64, 64, 192)  768         block3a_expand_convblock2[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activationblock2 (None, 64, 64, 192)  0           block3a_expand_bnblock2[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_38 (Conv2DTran (None, 64, 64, 144)  27648       block3a_expand_activationblock2[1
# __________________________________________________________________________________________________
# block2a_bnblock3 (BatchNormaliz (None, 64, 64, 144)  576         conv2d_transpose_38[0][0]
# __________________________________________________________________________________________________
# block2a_activationblock3 (Activ (None, 64, 64, 144)  0           block2a_bnblock3[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeezeblock3 (Globa (None, 144)          0           block2a_activationblock3[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshapeblock3 (Resha (None, 1, 1, 144)    0           block2a_se_squeezeblock3[1][0]
# __________________________________________________________________________________________________
# block2a_se_reduceblock3 (Conv2D (None, 1, 1, 6)      870         block2a_se_reshapeblock3[1][0]
# __________________________________________________________________________________________________
# block2a_se_expandblock3 (Conv2D (None, 1, 1, 144)    1008        block2a_se_reduceblock3[1][0]
# __________________________________________________________________________________________________
# multiply_69 (Multiply)          (None, 64, 64, 144)  0           block2a_activationblock3[1][0]
#                                                                  block2a_se_expandblock3[1][0]
# __________________________________________________________________________________________________
# block2a_project_convblock3 (Con (None, 64, 64, 32)   4608        multiply_69[0][0]
# __________________________________________________________________________________________________
# block2a_project_bnblock3 (Batch (None, 64, 64, 32)   128         block2a_project_convblock3[1][0]
# __________________________________________________________________________________________________
# block2b_expand_convblock3 (Conv (None, 64, 64, 192)  6144        block2a_project_bnblock3[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bnblock3 (BatchN (None, 64, 64, 192)  768         block2b_expand_convblock3[1][0]
# __________________________________________________________________________________________________
# block2b_expand_activationblock3 (None, 64, 64, 192)  0           block2b_expand_bnblock3[1][0]
# __________________________________________________________________________________________________
# block2b_dwconvblock3 (Depthwise (None, 64, 64, 192)  1728        block2b_expand_activationblock3[1
# __________________________________________________________________________________________________
# block2b_bnblock3 (BatchNormaliz (None, 64, 64, 192)  768         block2b_dwconvblock3[1][0]
# __________________________________________________________________________________________________
# block2b_activationblock3 (Activ (None, 64, 64, 192)  0           block2b_bnblock3[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeezeblock3 (Globa (None, 192)          0           block2b_activationblock3[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshapeblock3 (Resha (None, 1, 1, 192)    0           block2b_se_squeezeblock3[1][0]
# __________________________________________________________________________________________________
# block2b_se_reduceblock3 (Conv2D (None, 1, 1, 8)      1544        block2b_se_reshapeblock3[1][0]
# __________________________________________________________________________________________________
# block2b_se_expandblock3 (Conv2D (None, 1, 1, 192)    1728        block2b_se_reduceblock3[1][0]
# __________________________________________________________________________________________________
# multiply_70 (Multiply)          (None, 64, 64, 192)  0           block2b_activationblock3[1][0]
#                                                                  block2b_se_expandblock3[1][0]
# __________________________________________________________________________________________________
# block2b_project_convblock3 (Con (None, 64, 64, 32)   6144        multiply_70[0][0]
# __________________________________________________________________________________________________
# block2b_project_bnblock3 (Batch (None, 64, 64, 32)   128         block2b_project_convblock3[1][0]
# __________________________________________________________________________________________________
# block2b_dropblock3 (FixedDropou (None, 64, 64, 32)   0           block2b_project_bnblock3[1][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 64, 64, 32)   0           block2a_project_bnblock3[1][0]
#                                                                  block2b_dropblock3[1][0]
# __________________________________________________________________________________________________
# block2c_expand_convblock3 (Conv (None, 64, 64, 192)  6144        add_46[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bnblock3 (BatchN (None, 64, 64, 192)  768         block2c_expand_convblock3[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activationblock3 (None, 64, 64, 192)  0           block2c_expand_bnblock3[1][0]
# __________________________________________________________________________________________________
# block2c_dwconvblock3 (Depthwise (None, 64, 64, 192)  1728        block2c_expand_activationblock3[1
# __________________________________________________________________________________________________
# block2c_bnblock3 (BatchNormaliz (None, 64, 64, 192)  768         block2c_dwconvblock3[1][0]
# __________________________________________________________________________________________________
# block2c_activationblock3 (Activ (None, 64, 64, 192)  0           block2c_bnblock3[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeezeblock3 (Globa (None, 192)          0           block2c_activationblock3[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshapeblock3 (Resha (None, 1, 1, 192)    0           block2c_se_squeezeblock3[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduceblock3 (Conv2D (None, 1, 1, 8)      1544        block2c_se_reshapeblock3[1][0]
# __________________________________________________________________________________________________
# block2c_se_expandblock3 (Conv2D (None, 1, 1, 192)    1728        block2c_se_reduceblock3[1][0]
# __________________________________________________________________________________________________
# multiply_71 (Multiply)          (None, 64, 64, 192)  0           block2c_activationblock3[1][0]
#                                                                  block2c_se_expandblock3[1][0]
# __________________________________________________________________________________________________
# block2c_project_convblock3 (Con (None, 64, 64, 32)   6144        multiply_71[0][0]
# __________________________________________________________________________________________________
# block2c_project_bnblock3 (Batch (None, 64, 64, 32)   128         block2c_project_convblock3[1][0]
# __________________________________________________________________________________________________
# block2c_dropblock3 (FixedDropou (None, 64, 64, 32)   0           block2c_project_bnblock3[1][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 64, 64, 32)   0           add_46[0][0]
#                                                                  block2c_dropblock3[1][0]
# __________________________________________________________________________________________________
# block3a_expand_convblock3 (Conv (None, 64, 64, 192)  6144        add_47[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bnblock3 (BatchN (None, 64, 64, 192)  768         block3a_expand_convblock3[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activationblock3 (None, 64, 64, 192)  0           block3a_expand_bnblock3[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_39 (Conv2DTran (None, 64, 64, 144)  27648       block3a_expand_activationblock3[1
# __________________________________________________________________________________________________
# block2a_bnblock4 (BatchNormaliz (None, 64, 64, 144)  576         conv2d_transpose_39[0][0]
# __________________________________________________________________________________________________
# block2a_activationblock4 (Activ (None, 64, 64, 144)  0           block2a_bnblock4[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeezeblock4 (Globa (None, 144)          0           block2a_activationblock4[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshapeblock4 (Resha (None, 1, 1, 144)    0           block2a_se_squeezeblock4[1][0]
# __________________________________________________________________________________________________
# block2a_se_reduceblock4 (Conv2D (None, 1, 1, 6)      870         block2a_se_reshapeblock4[1][0]
# __________________________________________________________________________________________________
# block2a_se_expandblock4 (Conv2D (None, 1, 1, 144)    1008        block2a_se_reduceblock4[1][0]
# __________________________________________________________________________________________________
# multiply_72 (Multiply)          (None, 64, 64, 144)  0           block2a_activationblock4[1][0]
#                                                                  block2a_se_expandblock4[1][0]
# __________________________________________________________________________________________________
# block2a_project_convblock4 (Con (None, 64, 64, 32)   4608        multiply_72[0][0]
# __________________________________________________________________________________________________
# block2a_project_bnblock4 (Batch (None, 64, 64, 32)   128         block2a_project_convblock4[1][0]
# __________________________________________________________________________________________________
# block2b_expand_convblock4 (Conv (None, 64, 64, 192)  6144        block2a_project_bnblock4[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bnblock4 (BatchN (None, 64, 64, 192)  768         block2b_expand_convblock4[1][0]
# __________________________________________________________________________________________________
# block2b_expand_activationblock4 (None, 64, 64, 192)  0           block2b_expand_bnblock4[1][0]
# __________________________________________________________________________________________________
# block2b_dwconvblock4 (Depthwise (None, 64, 64, 192)  1728        block2b_expand_activationblock4[1
# __________________________________________________________________________________________________
# block2b_bnblock4 (BatchNormaliz (None, 64, 64, 192)  768         block2b_dwconvblock4[1][0]
# __________________________________________________________________________________________________
# block2b_activationblock4 (Activ (None, 64, 64, 192)  0           block2b_bnblock4[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeezeblock4 (Globa (None, 192)          0           block2b_activationblock4[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshapeblock4 (Resha (None, 1, 1, 192)    0           block2b_se_squeezeblock4[1][0]
# __________________________________________________________________________________________________
# block2b_se_reduceblock4 (Conv2D (None, 1, 1, 8)      1544        block2b_se_reshapeblock4[1][0]
# __________________________________________________________________________________________________
# block2b_se_expandblock4 (Conv2D (None, 1, 1, 192)    1728        block2b_se_reduceblock4[1][0]
# __________________________________________________________________________________________________
# multiply_73 (Multiply)          (None, 64, 64, 192)  0           block2b_activationblock4[1][0]
#                                                                  block2b_se_expandblock4[1][0]
# __________________________________________________________________________________________________
# block2b_project_convblock4 (Con (None, 64, 64, 32)   6144        multiply_73[0][0]
# __________________________________________________________________________________________________
# block2b_project_bnblock4 (Batch (None, 64, 64, 32)   128         block2b_project_convblock4[1][0]
# __________________________________________________________________________________________________
# block2b_dropblock4 (FixedDropou (None, 64, 64, 32)   0           block2b_project_bnblock4[1][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 64, 64, 32)   0           block2a_project_bnblock4[1][0]
#                                                                  block2b_dropblock4[1][0]
# __________________________________________________________________________________________________
# block2c_expand_convblock4 (Conv (None, 64, 64, 192)  6144        add_48[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bnblock4 (BatchN (None, 64, 64, 192)  768         block2c_expand_convblock4[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activationblock4 (None, 64, 64, 192)  0           block2c_expand_bnblock4[1][0]
# __________________________________________________________________________________________________
# block2c_dwconvblock4 (Depthwise (None, 64, 64, 192)  1728        block2c_expand_activationblock4[1
# __________________________________________________________________________________________________
# block2c_bnblock4 (BatchNormaliz (None, 64, 64, 192)  768         block2c_dwconvblock4[1][0]
# __________________________________________________________________________________________________
# block2c_activationblock4 (Activ (None, 64, 64, 192)  0           block2c_bnblock4[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeezeblock4 (Globa (None, 192)          0           block2c_activationblock4[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshapeblock4 (Resha (None, 1, 1, 192)    0           block2c_se_squeezeblock4[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduceblock4 (Conv2D (None, 1, 1, 8)      1544        block2c_se_reshapeblock4[1][0]
# __________________________________________________________________________________________________
# block2c_se_expandblock4 (Conv2D (None, 1, 1, 192)    1728        block2c_se_reduceblock4[1][0]
# __________________________________________________________________________________________________
# multiply_74 (Multiply)          (None, 64, 64, 192)  0           block2c_activationblock4[1][0]
#                                                                  block2c_se_expandblock4[1][0]
# __________________________________________________________________________________________________
# block2c_project_convblock4 (Con (None, 64, 64, 32)   6144        multiply_74[0][0]
# __________________________________________________________________________________________________
# block2c_project_bnblock4 (Batch (None, 64, 64, 32)   128         block2c_project_convblock4[1][0]
# __________________________________________________________________________________________________
# block2c_dropblock4 (FixedDropou (None, 64, 64, 32)   0           block2c_project_bnblock4[1][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 64, 64, 32)   0           add_48[0][0]
#                                                                  block2c_dropblock4[1][0]
# __________________________________________________________________________________________________
# block3a_expand_convblock4 (Conv (None, 64, 64, 192)  6144        add_49[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bnblock4 (BatchN (None, 64, 64, 192)  768         block3a_expand_convblock4[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activationblock4 (None, 64, 64, 192)  0           block3a_expand_bnblock4[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_40 (Conv2DTran (None, 64, 64, 144)  27648       block3a_expand_activationblock4[1
# __________________________________________________________________________________________________
# block2a_bnblock5 (BatchNormaliz (None, 64, 64, 144)  576         conv2d_transpose_40[0][0]
# __________________________________________________________________________________________________
# block2a_activationblock5 (Activ (None, 64, 64, 144)  0           block2a_bnblock5[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeezeblock5 (Globa (None, 144)          0           block2a_activationblock5[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshapeblock5 (Resha (None, 1, 1, 144)    0           block2a_se_squeezeblock5[1][0]
# __________________________________________________________________________________________________
# block2a_se_reduceblock5 (Conv2D (None, 1, 1, 6)      870         block2a_se_reshapeblock5[1][0]
# __________________________________________________________________________________________________
# block2a_se_expandblock5 (Conv2D (None, 1, 1, 144)    1008        block2a_se_reduceblock5[1][0]
# __________________________________________________________________________________________________
# multiply_75 (Multiply)          (None, 64, 64, 144)  0           block2a_activationblock5[1][0]
#                                                                  block2a_se_expandblock5[1][0]
# __________________________________________________________________________________________________
# block2a_project_convblock5 (Con (None, 64, 64, 32)   4608        multiply_75[0][0]
# __________________________________________________________________________________________________
# block2a_project_bnblock5 (Batch (None, 64, 64, 32)   128         block2a_project_convblock5[1][0]
# __________________________________________________________________________________________________
# block2b_expand_convblock5 (Conv (None, 64, 64, 192)  6144        block2a_project_bnblock5[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bnblock5 (BatchN (None, 64, 64, 192)  768         block2b_expand_convblock5[1][0]
# __________________________________________________________________________________________________
# block2b_expand_activationblock5 (None, 64, 64, 192)  0           block2b_expand_bnblock5[1][0]
# __________________________________________________________________________________________________
# block2b_dwconvblock5 (Depthwise (None, 64, 64, 192)  1728        block2b_expand_activationblock5[1
# __________________________________________________________________________________________________
# block2b_bnblock5 (BatchNormaliz (None, 64, 64, 192)  768         block2b_dwconvblock5[1][0]
# __________________________________________________________________________________________________
# block2b_activationblock5 (Activ (None, 64, 64, 192)  0           block2b_bnblock5[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeezeblock5 (Globa (None, 192)          0           block2b_activationblock5[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshapeblock5 (Resha (None, 1, 1, 192)    0           block2b_se_squeezeblock5[1][0]
# __________________________________________________________________________________________________
# block2b_se_reduceblock5 (Conv2D (None, 1, 1, 8)      1544        block2b_se_reshapeblock5[1][0]
# __________________________________________________________________________________________________
# block2b_se_expandblock5 (Conv2D (None, 1, 1, 192)    1728        block2b_se_reduceblock5[1][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 64, 64, 192)  0           block2b_activationblock5[1][0]
#                                                                  block2b_se_expandblock5[1][0]
# __________________________________________________________________________________________________
# block2b_project_convblock5 (Con (None, 64, 64, 32)   6144        multiply_76[0][0]
# __________________________________________________________________________________________________
# block2b_project_bnblock5 (Batch (None, 64, 64, 32)   128         block2b_project_convblock5[1][0]
# __________________________________________________________________________________________________
# block2b_dropblock5 (FixedDropou (None, 64, 64, 32)   0           block2b_project_bnblock5[1][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 64, 64, 32)   0           block2a_project_bnblock5[1][0]
#                                                                  block2b_dropblock5[1][0]
# __________________________________________________________________________________________________
# block2c_expand_convblock5 (Conv (None, 64, 64, 192)  6144        add_50[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bnblock5 (BatchN (None, 64, 64, 192)  768         block2c_expand_convblock5[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activationblock5 (None, 64, 64, 192)  0           block2c_expand_bnblock5[1][0]
# __________________________________________________________________________________________________
# block2c_dwconvblock5 (Depthwise (None, 64, 64, 192)  1728        block2c_expand_activationblock5[1
# __________________________________________________________________________________________________
# block2c_bnblock5 (BatchNormaliz (None, 64, 64, 192)  768         block2c_dwconvblock5[1][0]
# __________________________________________________________________________________________________
# block2c_activationblock5 (Activ (None, 64, 64, 192)  0           block2c_bnblock5[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeezeblock5 (Globa (None, 192)          0           block2c_activationblock5[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshapeblock5 (Resha (None, 1, 1, 192)    0           block2c_se_squeezeblock5[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduceblock5 (Conv2D (None, 1, 1, 8)      1544        block2c_se_reshapeblock5[1][0]
# __________________________________________________________________________________________________
# block2c_se_expandblock5 (Conv2D (None, 1, 1, 192)    1728        block2c_se_reduceblock5[1][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 64, 64, 192)  0           block2c_activationblock5[1][0]
#                                                                  block2c_se_expandblock5[1][0]
# __________________________________________________________________________________________________
# block2c_project_convblock5 (Con (None, 64, 64, 32)   6144        multiply_77[0][0]
# __________________________________________________________________________________________________
# block2c_project_bnblock5 (Batch (None, 64, 64, 32)   128         block2c_project_convblock5[1][0]
# __________________________________________________________________________________________________
# block2c_dropblock5 (FixedDropou (None, 64, 64, 32)   0           block2c_project_bnblock5[1][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 64, 64, 32)   0           add_50[0][0]
#                                                                  block2c_dropblock5[1][0]
# __________________________________________________________________________________________________
# block3a_expand_convblock5 (Conv (None, 64, 64, 192)  6144        add_51[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bnblock5 (BatchN (None, 64, 64, 192)  768         block3a_expand_convblock5[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activationblock5 (None, 64, 64, 192)  0           block3a_expand_bnblock5[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_41 (Conv2DTran (None, 64, 64, 144)  27648       block3a_expand_activationblock5[1
# __________________________________________________________________________________________________
# block2a_bnblock6 (BatchNormaliz (None, 64, 64, 144)  576         conv2d_transpose_41[0][0]
# __________________________________________________________________________________________________
# block2a_activationblock6 (Activ (None, 64, 64, 144)  0           block2a_bnblock6[1][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# block2b_project_convblock8 (Con (None, 64, 64, 32)   6144        multiply_85[0][0]
# __________________________________________________________________________________________________
# block2b_project_bnblock8 (Batch (None, 64, 64, 32)   128         block2b_project_convblock8[1][0]
# __________________________________________________________________________________________________
# block2b_dropblock8 (FixedDropou (None, 64, 64, 32)   0           block2b_project_bnblock8[1][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 64, 64, 32)   0           block2a_project_bnblock8[1][0]
#                                                                  block2b_dropblock8[1][0]
# __________________________________________________________________________________________________
# block2c_expand_convblock8 (Conv (None, 64, 64, 192)  6144        add_56[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bnblock8 (BatchN (None, 64, 64, 192)  768         block2c_expand_convblock8[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activationblock8 (None, 64, 64, 192)  0           block2c_expand_bnblock8[1][0]
# __________________________________________________________________________________________________
# block2c_dwconvblock8 (Depthwise (None, 64, 64, 192)  1728        block2c_expand_activationblock8[1
# __________________________________________________________________________________________________
# block2c_bnblock8 (BatchNormaliz (None, 64, 64, 192)  768         block2c_dwconvblock8[1][0]
# __________________________________________________________________________________________________
# block2c_activationblock8 (Activ (None, 64, 64, 192)  0           block2c_bnblock8[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeezeblock8 (Globa (None, 192)          0           block2c_activationblock8[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshapeblock8 (Resha (None, 1, 1, 192)    0           block2c_se_squeezeblock8[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduceblock8 (Conv2D (None, 1, 1, 8)      1544        block2c_se_reshapeblock8[1][0]
# __________________________________________________________________________________________________
# block2c_se_expandblock8 (Conv2D (None, 1, 1, 192)    1728        block2c_se_reduceblock8[1][0]
# __________________________________________________________________________________________________
# multiply_86 (Multiply)          (None, 64, 64, 192)  0           block2c_activationblock8[1][0]
#                                                                  block2c_se_expandblock8[1][0]
# __________________________________________________________________________________________________
# block2c_project_convblock8 (Con (None, 64, 64, 32)   6144        multiply_86[0][0]
# __________________________________________________________________________________________________
# block2c_project_bnblock8 (Batch (None, 64, 64, 32)   128         block2c_project_convblock8[1][0]
# __________________________________________________________________________________________________
# block2c_dropblock8 (FixedDropou (None, 64, 64, 32)   0           block2c_project_bnblock8[1][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 64, 64, 32)   0           add_56[0][0]
#                                                                  block2c_dropblock8[1][0]
# __________________________________________________________________________________________________
# block3a_expand_convblock8 (Conv (None, 64, 64, 192)  6144        add_57[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bnblock8 (BatchN (None, 64, 64, 192)  768         block3a_expand_convblock8[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activationblock8 (None, 64, 64, 192)  0           block3a_expand_bnblock8[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_44 (Conv2DTran (None, 64, 64, 144)  27648       block3a_expand_activationblock8[1
# __________________________________________________________________________________________________
# block2a_bnblock9 (BatchNormaliz (None, 64, 64, 144)  576         conv2d_transpose_44[0][0]
# __________________________________________________________________________________________________
# block2a_activationblock9 (Activ (None, 64, 64, 144)  0           block2a_bnblock9[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeezeblock9 (Globa (None, 144)          0           block2a_activationblock9[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshapeblock9 (Resha (None, 1, 1, 144)    0           block2a_se_squeezeblock9[1][0]
# __________________________________________________________________________________________________
# block2a_se_reduceblock9 (Conv2D (None, 1, 1, 6)      870         block2a_se_reshapeblock9[1][0]
# __________________________________________________________________________________________________
# block2a_se_expandblock9 (Conv2D (None, 1, 1, 144)    1008        block2a_se_reduceblock9[1][0]
# __________________________________________________________________________________________________
# multiply_87 (Multiply)          (None, 64, 64, 144)  0           block2a_activationblock9[1][0]
#                                                                  block2a_se_expandblock9[1][0]
# __________________________________________________________________________________________________
# block2a_project_convblock9 (Con (None, 64, 64, 32)   4608        multiply_87[0][0]
# __________________________________________________________________________________________________
# block2a_project_bnblock9 (Batch (None, 64, 64, 32)   128         block2a_project_convblock9[1][0]
# __________________________________________________________________________________________________
# block2b_expand_convblock9 (Conv (None, 64, 64, 192)  6144        block2a_project_bnblock9[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bnblock9 (BatchN (None, 64, 64, 192)  768         block2b_expand_convblock9[1][0]
# __________________________________________________________________________________________________
# block2b_expand_activationblock9 (None, 64, 64, 192)  0           block2b_expand_bnblock9[1][0]
# __________________________________________________________________________________________________
# block2b_dwconvblock9 (Depthwise (None, 64, 64, 192)  1728        block2b_expand_activationblock9[1
# __________________________________________________________________________________________________
# block2b_bnblock9 (BatchNormaliz (None, 64, 64, 192)  768         block2b_dwconvblock9[1][0]
# __________________________________________________________________________________________________
# block2b_activationblock9 (Activ (None, 64, 64, 192)  0           block2b_bnblock9[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeezeblock9 (Globa (None, 192)          0           block2b_activationblock9[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshapeblock9 (Resha (None, 1, 1, 192)    0           block2b_se_squeezeblock9[1][0]
# __________________________________________________________________________________________________
# block2b_se_reduceblock9 (Conv2D (None, 1, 1, 8)      1544        block2b_se_reshapeblock9[1][0]
# __________________________________________________________________________________________________
# block2b_se_expandblock9 (Conv2D (None, 1, 1, 192)    1728        block2b_se_reduceblock9[1][0]
# __________________________________________________________________________________________________
# multiply_88 (Multiply)          (None, 64, 64, 192)  0           block2b_activationblock9[1][0]
#                                                                  block2b_se_expandblock9[1][0]
# __________________________________________________________________________________________________
# block2b_project_convblock9 (Con (None, 64, 64, 32)   6144        multiply_88[0][0]
# __________________________________________________________________________________________________
# block2b_project_bnblock9 (Batch (None, 64, 64, 32)   128         block2b_project_convblock9[1][0]
# __________________________________________________________________________________________________
# block2b_dropblock9 (FixedDropou (None, 64, 64, 32)   0           block2b_project_bnblock9[1][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 64, 64, 32)   0           block2a_project_bnblock9[1][0]
#                                                                  block2b_dropblock9[1][0]
# __________________________________________________________________________________________________
# block2c_expand_convblock9 (Conv (None, 64, 64, 192)  6144        add_58[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bnblock9 (BatchN (None, 64, 64, 192)  768         block2c_expand_convblock9[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activationblock9 (None, 64, 64, 192)  0           block2c_expand_bnblock9[1][0]
# __________________________________________________________________________________________________
# block2c_dwconvblock9 (Depthwise (None, 64, 64, 192)  1728        block2c_expand_activationblock9[1
# __________________________________________________________________________________________________
# block2c_bnblock9 (BatchNormaliz (None, 64, 64, 192)  768         block2c_dwconvblock9[1][0]
# __________________________________________________________________________________________________
# block2c_activationblock9 (Activ (None, 64, 64, 192)  0           block2c_bnblock9[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeezeblock9 (Globa (None, 192)          0           block2c_activationblock9[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshapeblock9 (Resha (None, 1, 1, 192)    0           block2c_se_squeezeblock9[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduceblock9 (Conv2D (None, 1, 1, 8)      1544        block2c_se_reshapeblock9[1][0]
# __________________________________________________________________________________________________
# block2c_se_expandblock9 (Conv2D (None, 1, 1, 192)    1728        block2c_se_reduceblock9[1][0]
# __________________________________________________________________________________________________
# multiply_89 (Multiply)          (None, 64, 64, 192)  0           block2c_activationblock9[1][0]
#                                                                  block2c_se_expandblock9[1][0]
# __________________________________________________________________________________________________
# block2c_project_convblock9 (Con (None, 64, 64, 32)   6144        multiply_89[0][0]
# __________________________________________________________________________________________________
# block2c_project_bnblock9 (Batch (None, 64, 64, 32)   128         block2c_project_convblock9[1][0]
# __________________________________________________________________________________________________
# block2c_dropblock9 (FixedDropou (None, 64, 64, 32)   0           block2c_project_bnblock9[1][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 64, 64, 32)   0           add_58[0][0]
#                                                                  block2c_dropblock9[1][0]
# __________________________________________________________________________________________________
# block3a_expand_convblock9 (Conv (None, 64, 64, 192)  6144        add_59[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bnblock9 (BatchN (None, 64, 64, 192)  768         block3a_expand_convblock9[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activationblock9 (None, 64, 64, 192)  0           block3a_expand_bnblock9[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_45 (Conv2DTran (None, 64, 64, 144)  27648       block3a_expand_activationblock9[1
# __________________________________________________________________________________________________
# conv2d_transpose_46 (Conv2DTran (None, 128, 128, 64) 82944       conv2d_transpose_45[0][0]
# __________________________________________________________________________________________________
# instance_normalization_77 (Inst (None, 128, 128, 64) 128         conv2d_transpose_46[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 128, 128, 64) 0           instance_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_47 (Conv2DTran (None, 256, 256, 3)  1728        activation_84[0][0]
# __________________________________________________________________________________________________
# instance_normalization_78 (Inst (None, 256, 256, 3)  6           conv2d_transpose_47[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 256, 256, 3)  0           instance_normalization_78[0][0]
# __________________________________________________________________________________________________
# reflection_padding2d_28 (Reflec (None, 262, 262, 3)  0           activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 256, 256, 3)  444         reflection_padding2d_28[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 256, 256, 3)  0           conv2d_70[0][0]
# ==================================================================================================
# Total params: 931,896
# Trainable params: 910,296
# Non-trainable params: 21,600
# __________________________________________________________________________________________________
